# %% [markdown]
# 1. What are the differences between operators and values in the following?
#
# * - Multiplication Operator
# 'hello' - String Value
# -87.8 - float
# -  subtraction operator
# / - division operator
# + - addition operator
# 6 - int
#
#
# 2. What is the difference between string and variable?
#
# spam can be used as variable which can hold data related to any data type
# 'spam' is data of data type str
#
# 3. Describe three different data forms.
#
# int - it represents data with any numeric value without decimals.
# float - it represents data with any numeric value with decimals
# str - it represent data with sequece of characters
#
# 4. What makes up an expression? What are the functions of all expressions?
#
# expression is combination of variables,values and operators. The function of expression is to calculate a value.
#
# 5. In this chapter, assignment statements such as spam = 10 were added. What's the
# difference between a declaration and an expression?
#
# Declaration is used to tell a particular variable to hold a data with a particular datatype whereas expression is used to calculate the value using variables, values and operators
#
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# bacon contains the value 22
#
# 7. What should the values of the following two terms be?
#
# 'spam' + 'spamspam'
# 'spam' * 3
#
#
# 'spamspamspam' is the value of 'spam' + 'spamspam'
# 'spamspamspam' is the value of 'spam' * 3
#
# observation: both the values are same.
#
# 8. Why is it that eggs is a true variable name but 100 is not?
#
# Variable name can start with alphabet or underscore. It can not start with number.
#
# 9. Which of the following three functions may be used to convert a value to an integer, a
# floating-point number, or a string?
#
# int() is used to convert a value to integer.
# float() is used to convert a value to a floating-point number
# str() is used to convert a value to a string
#
# 10. What is the error caused by this expression? What would you do about it?
#
# Below error is cause by the expression.
#
# 'I have eaten ' + 99 + ' burritos.'
#
# TypeError: can only concatenate str (not "int") to str
#
# Correct expression is
#
# 'I have eaten ' + str(99) + ' burritos.'
